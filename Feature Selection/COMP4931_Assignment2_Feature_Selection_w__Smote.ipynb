# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_excel("TrainDataset2024.xls")

# %%
df.head()
# Out:
#           ID  pCR (outcome)  RelapseFreeSurvival (outcome)   Age  ER  PgR  \
# 0  TRG002174              1                          144.0  41.0   0    0
# 1  TRG002178              0                          142.0  39.0   1    1
# 2  TRG002204              1                          135.0  31.0   0    0
# 3  TRG002206              0                           12.0  35.0   0    0
# 4  TRG002210              0                          109.0  61.0   1    0
#
#    HER2  TrippleNegative  ChemoGrade  Proliferation  ...  \
# 0     0                1           3              3  ...
# 1     0                0           3              3  ...
# 2     0                1           2              1  ...
# 3     0                1           3              3  ...
# 4     0                0           2              1  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       0.517172
# 1                                       0.444391
# ...

# %%
df.describe()
# Out:
#        pCR (outcome)  RelapseFreeSurvival (outcome)         Age          ER  \
# count     400.000000                     400.000000  400.000000  400.000000
# mean       12.697500                      56.000208   51.804674    0.547500
# std       111.107417                      27.137584   10.948522    0.498362
# min         0.000000                       0.000000   23.000000    0.000000
# 25%         0.000000                      38.000000   44.516769    0.000000
# 50%         0.000000                      55.000000   51.019507    1.000000
# 75%         0.000000                      73.000000   60.000000    1.000000
# max       999.000000                     144.000000   79.603012    1.000000
#
#               PgR        HER2  TrippleNegative  ChemoGrade  Proliferation  \
# count  400.000000  400.000000       400.000000  400.000000     400.000000
# mean     2.902500    2.797500         2.830000    9.875000       6.562500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Columns: 121 entries, ID to original_ngtdm_Strength
# dtypes: float64(108), int64(12), object(1)
# memory usage: 378.2+ KB

# %%
df.drop("ID", axis=1, inplace=True)
df.head()
# Out:
#    pCR (outcome)  RelapseFreeSurvival (outcome)   Age  ER  PgR  HER2  \
# 0              1                          144.0  41.0   0    0     0
# 1              0                          142.0  39.0   1    1     0
# 2              1                          135.0  31.0   0    0     0
# 3              0                           12.0  35.0   0    0     0
# 4              0                          109.0  61.0   1    0     0
#
#    TrippleNegative  ChemoGrade  Proliferation  HistologyType  ...  \
# 0                1           3              3              1  ...
# 1                0           3              3              1  ...
# 2                1           2              1              1  ...
# 3                1           3              3              1  ...
# 4                0           2              1              1  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       0.517172
# 1                                       0.444391
# ...

# %% [markdown]
# # Data Imputation

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')

df.replace(999, np.nan, inplace=True)

df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
df.describe()
# Out:
#        pCR (outcome)  RelapseFreeSurvival (outcome)         Age          ER  \
# count     400.000000                     400.000000  400.000000  400.000000
# mean        0.210000                      56.000208   51.804674    0.547500
# std         0.407818                      27.137584   10.948522    0.498362
# min         0.000000                       0.000000   23.000000    0.000000
# 25%         0.000000                      38.000000   44.516769    0.000000
# 50%         0.000000                      55.000000   51.019507    1.000000
# 75%         0.000000                      73.000000   60.000000    1.000000
# max         1.000000                     144.000000   79.603012    1.000000
#
#               PgR        HER2  TrippleNegative  ChemoGrade  Proliferation  \
# count  400.000000  400.000000       400.000000  400.000000     400.000000
# mean     0.405000    0.300000         0.332500    2.397500       1.572500
# ...

# %%
import seaborn as sns

print(df['pCR (outcome)'].value_counts())
sns.countplot(x="pCR (outcome)", data=df)
# Out:
# pCR (outcome)
# 0.0    316
# 1.0     84
# Name: count, dtype: int64
# <Axes: xlabel='pCR (outcome)', ylabel='count'>

# %%
y_class = df["pCR (outcome)"]
y_reg = df["RelapseFreeSurvival (outcome)"]
df.drop("pCR (outcome)", axis=1, inplace=True)
df.drop("RelapseFreeSurvival (outcome)", axis=1, inplace=True)

# %%
df.head()
# Out:
#     Age   ER  PgR  HER2  TrippleNegative  ChemoGrade  Proliferation  \
# 0  41.0  0.0  0.0   0.0              1.0         3.0            3.0
# 1  39.0  1.0  1.0   0.0              0.0         3.0            3.0
# 2  31.0  0.0  0.0   0.0              1.0         2.0            1.0
# 3  35.0  0.0  0.0   0.0              1.0         3.0            3.0
# 4  61.0  1.0  0.0   0.0              0.0         2.0            1.0
#
#    HistologyType  LNStatus  TumourStage  ...  \
# 0            1.0       1.0          2.0  ...
# 1            1.0       1.0          2.0  ...
# 2            1.0       0.0          2.0  ...
# 3            1.0       1.0          3.0  ...
# 4            1.0       0.0          2.0  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       0.517172
# 1                                       0.444391
# 2                                       0.534549
# 3                                       0.506185
# ...

# %%
X_clinical = df.iloc[:, :11]
X_mri = df.iloc[:, 11:]

# %% [markdown]
# # Recursive Feature Elimination (RFE) on Clinical Features

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier

model_all = RandomForestClassifier(random_state=42)
model_all.fit(X_clinical, y_class)

all_importances = model_all.feature_importances_
indices = np.argsort(all_importances)[::-1]

plt.figure()
plt.title("Feature Importances of All Clinical Features")
plt.bar(X_clinical.columns[indices], all_importances[indices], color="lightsalmon", align="center")
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.tight_layout()
plt.show()

# %%
model = RandomForestClassifier(random_state=42)

rfecv = RFECV(estimator=model, step=1, cv=5, scoring='accuracy')
rfecv.fit(X_clinical, y_class)

selected_features = X_clinical.columns[rfecv.support_]
print("Optimal Number of Features:", rfecv.n_features_)
print("Selected Features:")
print(selected_features)
# Out:
# Optimal Number of Features: 9
# Selected Features:
# Index(['Age', 'ER', 'PgR', 'HER2', 'ChemoGrade', 'Proliferation', 'LNStatus',
#        'TumourStage', 'Gene'],
#       dtype='object')

# %%
X_clinical_fs = X_clinical[selected_features]

# %% [markdown]
# # Dimensionality Reduction on MRI Features

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95)
X_mri_dr = pca.fit_transform(X_mri)

print("Number of Components Selected:", pca.n_components_)
# Out:
# Number of Components Selected: 2

# %%
print(X_clinical_fs.shape, type(X_clinical_fs))
print(X_mri_dr.shape, type(X_mri_dr))
# Out:
# (400, 9) <class 'pandas.core.frame.DataFrame'>
# (400, 2) <class 'numpy.ndarray'>

# %%
X = np.hstack((X_clinical_fs.values, X_mri_dr))

# %%
X.shape, type(X.shape)
# Out:
# ((400, 11), tuple)

# %%
print(y_class.value_counts())
#sns.countplot(x="pCR (outcome)", data=df)
# Out:
# pCR (outcome)
# 0.0    316
# 1.0     84
# Name: count, dtype: int64

# %% [markdown]
# # Z-score Distribution

# %%
from scipy.stats import zscore

z_scores = np.abs(zscore(df))
z_scores = z_scores.to_numpy()
z_scores_flat = z_scores.flatten()

plt.figure(figsize=(10, 6))
sns.histplot(z_scores_flat, bins=30, kde=True)
plt.title("Distribution of Z-Scores")
plt.xlabel("Z-Score")
plt.ylabel("Frequency")
plt.axvline(x=3, color='r', linestyle='--', label="Outlier threshold = 3 ")
plt.legend()
plt.show()

# %% [markdown]
# # Data Splitting

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_class, test_size=0.30, random_state=42, stratify=y_class)

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc


# Calculate class weights
class_counts = np.bincount(y_train.astype(int))
total_samples = len(y_train)
num_classes = len(class_counts)

class_weights = {}
for i, count in enumerate(class_counts):
    class_weights[i] = total_samples / (num_classes * count)

# Assign weights to each sample
sample_weights = []
for label in y_train:
    sample_weights.append(class_weights[int(label)])
sample_weights = np.array(sample_weights)

gbc = GradientBoostingClassifier(random_state=42, loss='log_loss', subsample=0.8, n_estimators=100, learning_rate=0.1, max_depth=3)
gbc.fit(X_train, y_train, sample_weight=sample_weights)
y_pred = gbc.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.82      0.83        95
#          1.0       0.39      0.44      0.42        25
#
#     accuracy                           0.74       120
#    macro avg       0.62      0.63      0.62       120
# weighted avg       0.75      0.74      0.75       120
#
# Confusion Matrix:
# [[78 17]
#  [14 11]]

# %% [markdown]
# # ROC Curve

# %%
# Calculate ROC curve
y_pred_proba = gbc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Calculate AUC
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--', label='Random Chance')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %% [markdown]
# ## RFC

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
print(f"Model Accuracy: {accuracy}")
print("Classification Report:")
print(report)
# Out:
# Model Accuracy: 0.7583333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.92      0.86        95
#          1.0       0.33      0.16      0.22        25
#
#     accuracy                           0.76       120
#    macro avg       0.57      0.54      0.54       120
# weighted avg       0.71      0.76      0.72       120

# %% [markdown]
# # SMOTE

# %% [markdown]
# Reference from : https://towardsdatascience.com/upsampling-with-smote-for-classification-projects-e91d7c44e4bf

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, precision_recall_curve, roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt

# 1. Resampling with SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_res, y_res = smote.fit_resample(X_train, y_train)

# 2. Compute class weights (Optional: you can use this with Random Forest if you don't use SMOTE)
# class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
# class_weights_dict = dict(zip(np.unique(y_train), class_weights))

# 3. Random Forest with class_weight='balanced'
rf = RandomForestClassifier(class_weight='balanced', random_state=42)

# 4. Hyperparameter tuning with GridSearchCV (if desired)
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='f1', verbose=1)
grid_search.fit(X_res, y_res)

# Best model from GridSearchCV
best_rf = grid_search.best_estimator_

# 5. Train the model
best_rf.fit(X_res, y_res)

# 6. Make predictions
y_pred = best_rf.predict(X_test)
y_pred_proba = best_rf.predict_proba(X_test)[:, 1]

# 7. Evaluation: Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred))

# 8. Precision-Recall Curve
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# 9. ROC AUC Score
roc_auc = roc_auc_score(y_test, y_pred_proba)
print(f"ROC AUC Score: {roc_auc:.4f}")

# 10. Feature Importances (Optional)
# Convert X to a DataFrame (if it is not already one) and set the feature names
X = pd.DataFrame(X, columns=[f"feature_{i+1}" for i in range(X.shape[1])])

# Now you can use the feature names as expected
importances = best_rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("\nFeature Importances (top 5):")
for i in range(5):
    print(f"{X.columns[indices[i]]}: {importances[indices[i]]:.4f}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.89      0.85        95
#          1.0       0.38      0.24      0.29        25
#
#     accuracy                           0.76       120
#    macro avg       0.60      0.57      0.57       120
# weighted avg       0.73      0.76      0.74       120
# ROC AUC Score: 0.6998
#
# Feature Importances (top 5):
# feature_9: 0.1663
# feature_4: 0.1624
# feature_11: 0.1008
# feature_10: 0.0995
# feature_3: 0.0958

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, precision_recall_curve, roc_auc_score
from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# 1. Resampling with SMOTE (or try BorderlineSMOTE)
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)  # Use BorderlineSMOTE for better oversampling
X_res, y_res = smote.fit_resample(X_train, y_train)

# 2. Hyperparameter tuning with GridSearchCV (using 'recall' as scoring metric)
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}
grid_search = GridSearchCV(RandomForestClassifier(class_weight='balanced', random_state=42),
                           param_grid, cv=5, scoring='recall', verbose=1)
grid_search.fit(X_res, y_res)

# Best model from GridSearchCV
best_rf = grid_search.best_estimator_

# 3. Train the model
best_rf.fit(X_res, y_res)

# 4. Make predictions
y_pred = best_rf.predict(X_test)
y_pred_proba = best_rf.predict_proba(X_test)[:, 1]

# 5. Evaluate the model: Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred))

# 6. Precision-Recall Curve
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# 7. ROC AUC Score
roc_auc = roc_auc_score(y_test, y_pred_proba)
print(f"ROC AUC Score: {roc_auc:.4f}")

# 8. Adjusting the decision threshold (to improve recall for class 1)
threshold = 0.3  # Lowering the threshold to 0.3
y_pred_adjusted = (y_pred_proba > threshold).astype(int)

# 9. Classification Report after adjusting threshold
print("Classification Report (Adjusted Threshold):\n", classification_report(y_test, y_pred_adjusted))

# 10. Feature Importances (Random Forest Model)
importances = best_rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Assuming you are using a DataFrame, or use a list of feature names if X is a numpy array
feature_names = [f"feature_{i+1}" for i in range(X.shape[1])]  # If X is a numpy array

print("\nFeature Importances (top 5):")
for i in range(5):
    print(f"{feature_names[indices[i]]}: {importances[indices[i]]:.4f}")

# 11. Optionally, try an alternative model like XGBoost with `scale_pos_weight` to handle class imbalance
xgb = XGBClassifier(scale_pos_weight=3, random_state=42)  # Adjust scale_pos_weight based on the class imbalance ratio
xgb.fit(X_res, y_res)

# 12. Evaluate XGBoost model
y_pred_xgb = xgb.predict(X_test)
y_pred_proba_xgb = xgb.predict_proba(X_test)[:, 1]

print("XGBoost Classification Report:\n", classification_report(y_test, y_pred_xgb))

# 13. Precision-Recall Curve for XGBoost
precision_xgb, recall_xgb, thresholds_xgb = precision_recall_curve(y_test, y_pred_proba_xgb)

plt.figure(figsize=(8, 6))
plt.plot(recall_xgb, precision_xgb, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (XGBoost)')
plt.show()

# 14. ROC AUC Score for XGBoost
roc_auc_xgb = roc_auc_score(y_test, y_pred_proba_xgb)
print(f"XGBoost ROC AUC Score: {roc_auc_xgb:.4f}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.81      0.88      0.84        95
#          1.0       0.31      0.20      0.24        25
#
#     accuracy                           0.74       120
#    macro avg       0.56      0.54      0.54       120
# weighted avg       0.70      0.74      0.72       120
# ROC AUC Score: 0.7120
# Classification Report (Adjusted Threshold):
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.76      0.81        95
#          1.0       0.38      0.56      0.45        25
#
#     accuracy                           0.72       120
#    macro avg       0.62      0.66      0.63       120
# weighted avg       0.77      0.72      0.73       120
#
#
# Feature Importances (top 5):
# feature_4: 0.1300
# feature_3: 0.1178
# feature_9: 0.1137
# feature_11: 0.1114
# feature_10: 0.1025
# ...

# %% [markdown]
# ---

# %%
def upsample_SMOTE(X_train, y_train, ratio=1.0):
    """Upsamples minority class using SMOTE.
    Ratio argument is the percentage of the upsampled minority class in relation
    to the majority class. Default is 1.0
    """
    sm = SMOTE(random_state=42, sampling_strategy=ratio)
    X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)
    print(len(X_train_sm), len(y_train_sm))
    return X_train_sm, y_train_sm

# %%
X_train_sm, y_train_sm = upsample_SMOTE(X_train, y_train, ratio=1.0)
# Out:
# 442 442

# %%
X_train_sm.shape, type(X_train_sm.shape)
# Out:
# ((442, 11), tuple)

# %%
y_train_sm.shape, type(y_train_sm.shape)
# Out:
# ((442,), tuple)

# %%
print(y_train_sm.value_counts())
# Out:
# pCR (outcome)
# 0.0    171
# 1.0    171
# Name: count, dtype: int64

# %% [markdown]
# ## Gradient Boosting

# %%
# Calculate class weights
class_counts = np.bincount(y_train_sm.astype(int))
total_samples = len(y_train_sm)
num_classes = len(class_counts)

class_weights = {}
for i, count in enumerate(class_counts):
    class_weights[i] = total_samples / (num_classes * count)

# Assign weights to each sample
sample_weights = []
for label in y_train_sm:
    sample_weights.append(class_weights[int(label)])
sample_weights = np.array(sample_weights)

gbc = GradientBoostingClassifier(random_state=42, loss='log_loss', subsample=0.8, n_estimators=100, learning_rate=0.1, max_depth=3)
gbc.fit(X_train_sm, y_train_sm, sample_weight=sample_weights)
y_pred = gbc.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.89      0.86        95
#          1.0       0.44      0.32      0.37        25
#
#     accuracy                           0.78       120
#    macro avg       0.64      0.61      0.62       120
# weighted avg       0.75      0.78      0.76       120
#
# Confusion Matrix:
# [[85 10]
#  [17  8]]

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_sm, y_train_sm)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
print(f"Model Accuracy: {accuracy}")
print("Classification Report:")
print(report)
# Out:
# Model Accuracy: 0.7583333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.89      0.85        95
#          1.0       0.38      0.24      0.29        25
#
#     accuracy                           0.76       120
#    macro avg       0.60      0.57      0.57       120
# weighted avg       0.73      0.76      0.74       120

# %%
sm = SMOTE(random_state=42, sampling_strategy=1.0)
X_train_sm2, y_train_sm2 = sm.fit_resample(X_train, y_train)

# Train a model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(class_weight='balanced', random_state=42)
model.fit(X_train_sm2, y_train_sm2)

# Evaluate the model
from sklearn.metrics import classification_report, confusion_matrix
y_pred = model.predict(X_test)

print("Classification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.89      0.85        95
#          1.0       0.38      0.24      0.29        25
#
#     accuracy                           0.76       120
#    macro avg       0.60      0.57      0.57       120
# weighted avg       0.73      0.76      0.74       120
#
#
# Confusion Matrix:
#  [[85 10]
#  [19  6]]

# %%
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split


# Apply Borderline-SMOTE
sm = BorderlineSMOTE(random_state=42)
X_train_sm3, y_train_sm3 = sm.fit_resample(X_train, y_train)

# Train a model
model = RandomForestClassifier(class_weight='balanced', random_state=42)
model.fit(X_train_sm3, y_train_sm3)

# Predict and evaluate
y_pred = model.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.89      0.85        95
#          1.0       0.38      0.24      0.29        25
#
#     accuracy                           0.76       120
#    macro avg       0.60      0.57      0.57       120
# weighted avg       0.73      0.76      0.74       120
#
#
# Confusion Matrix:
#  [[85 10]
#  [19  6]]

# %%
from sklearn.model_selection import train_test_split
from imblearn.combine import SMOTETomek
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Apply SMOTETomek
smote_tomek = SMOTETomek(random_state=42)
X_train_sm, y_train_sm = smote_tomek.fit_resample(X_train, y_train)

# Train the model
model = RandomForestClassifier(class_weight='balanced', random_state=42)
model.fit(X_train_sm, y_train_sm)

# Predict and evaluate
y_pred = model.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.81      0.89      0.85        95
#          1.0       0.33      0.20      0.25        25
#
#     accuracy                           0.75       120
#    macro avg       0.57      0.55      0.55       120
# weighted avg       0.71      0.75      0.72       120
#
#
# Confusion Matrix:
#  [[85 10]
#  [20  5]]

# %% [markdown]
# ---
